# %% [markdown]
# ### Exploração de Dataset Simples
#
# #### "MICRODADOS DO ENEM 2024" / "RESULTADOS_2024"

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.5

# %%
df = pd.read_csv(
    "../../../data/raw/enem/microdados_enem_2024/DADOS/RESULTADOS_2024.csv",
    sep=";",
    encoding="latin-1"
)

# %%
df.shape
# Out:
# (4332944, 42)

# %%
df.head()
# Out:
#    NU_SEQUENCIAL  NU_ANO   CO_ESCOLA  CO_MUNICIPIO_ESC  \
# 0         206403    2024  23052929.0         2301406.0
# 1        3604651    2024  42103770.0         4218004.0
# 2        1461268    2024         NaN               NaN
# 3        4301058    2024         NaN               NaN
# 4        3148322    2024  21150354.0         2100436.0
#
#           NO_MUNICIPIO_ESC  CO_UF_ESC SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 0                  Aratuba       23.0        CE                     2.0
# 1                  Tijucas       42.0        SC                     4.0
# 2                      NaN        NaN       NaN                     NaN
# 3                      NaN        NaN       NaN                     NaN
# 4  Alto Alegre do Maranhão       21.0        MA                     2.0
#
#    TP_LOCALIZACAO_ESC  TP_SIT_FUNC_ESC  ...  \
# 0                 1.0              1.0  ...
# 1                 1.0              1.0  ...
# 2                 NaN              NaN  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4332944 entries, 0 to 4332943
# Data columns (total 42 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   NU_SEQUENCIAL           int64
#  1   NU_ANO                  int64
#  2   CO_ESCOLA               float64
#  3   CO_MUNICIPIO_ESC        float64
#  4   NO_MUNICIPIO_ESC        str
#  5   CO_UF_ESC               float64
#  6   SG_UF_ESC               str
#  7   TP_DEPENDENCIA_ADM_ESC  float64
#  8   TP_LOCALIZACAO_ESC      float64
#  9   TP_SIT_FUNC_ESC         float64
#  10  CO_MUNICIPIO_PROVA      int64
#  11  NO_MUNICIPIO_PROVA      str
#  12  CO_UF_PROVA             int64
#  13  SG_UF_PROVA             str
#  14  TP_PRESENCA_CN          int64
#  15  TP_PRESENCA_CH          int64
#  16  TP_PRESENCA_LC          int64
#  17  TP_PRESENCA_MT          int64
#  18  CO_PROVA_CN             float64
#  19  CO_PROVA_CH             float64
#  20  CO_PROVA_LC             float64
# ...

# %%
df.describe(include="all")
# Out:
#         NU_SEQUENCIAL     NU_ANO     CO_ESCOLA  CO_MUNICIPIO_ESC  \
# count    4.332944e+06  4332944.0  1.565797e+06      1.565797e+06
# unique            NaN        NaN           NaN               NaN
# top               NaN        NaN           NaN               NaN
# freq              NaN        NaN           NaN               NaN
# mean     2.166472e+06     2024.0  3.183945e+07      3.146948e+06
# std      1.250813e+06        0.0  1.042224e+07      9.964620e+05
# min      1.000000e+00     2024.0  1.100006e+07      1.100015e+06
# 25%      1.083237e+06     2024.0  2.502085e+07      2.500502e+06
# 50%      2.166472e+06     2024.0  3.120025e+07      3.148103e+06
# 75%      3.249708e+06     2024.0  3.556817e+07      3.550308e+06
# max      4.332944e+06     2024.0  6.002939e+07      5.300108e+06
#
#        NO_MUNICIPIO_ESC     CO_UF_ESC SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# count           1565797  1.565797e+06   1565797            1.565797e+06
# ...
