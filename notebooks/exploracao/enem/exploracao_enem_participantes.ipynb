# %% [markdown]
# ### Exploração de Dataset Simples
#
# #### "MICRODADOS DO ENEM 2024" / "PARTICIPANTES_2024"

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.5

# %%
df = pd.read_csv(
    "../../../data/raw/enem/microdados_enem_2024/DADOS/PARTICIPANTES_2024.csv",
    sep=";",
    encoding="latin-1"
)

# %%
df.shape
# Out:
# (4332944, 38)

# %%
df.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210062064233    2024                5       F                1
# 1  210062064234    2024               11       F                1
# 2  210062064235    2024               11       F                1
# 3  210062064236    2024                3       F                1
# 4  210062064237    2024               16       M                3
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ENSINO  \
# 0            1                 1                1                3        NaN
# 1            1                 1                1               10        NaN
# 2            1                 1                1                9        NaN
# 3            3                 1                2                0        1.0
# 4            1                 1                1               18        NaN
#
#    ...  Q014  Q015 Q016  Q017 Q018 Q019 Q020 Q021 Q022  Q023
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4332944 entries, 0 to 4332943
# Data columns (total 38 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   NU_INSCRICAO        int64
#  1   NU_ANO              int64
#  2   TP_FAIXA_ETARIA     int64
#  3   TP_SEXO             str
#  4   TP_ESTADO_CIVIL     int64
#  5   TP_COR_RACA         int64
#  6   TP_NACIONALIDADE    int64
#  7   TP_ST_CONCLUSAO     int64
#  8   TP_ANO_CONCLUIU     int64
#  9   TP_ENSINO           float64
#  10  IN_TREINEIRO        int64
#  11  CO_MUNICIPIO_PROVA  int64
#  12  NO_MUNICIPIO_PROVA  str
#  13  CO_UF_PROVA         int64
#  14  SG_UF_PROVA         str
#  15  Q001                str
#  16  Q002                str
#  17  Q003                str
#  18  Q004                str
#  19  Q005                int64
#  20  Q006                str
#  21  Q007                str
#  22  Q008                str
#  23  Q009                str
#  24  Q010                str
# ...

# %%
df.describe(include="all")
# Out:
#         NU_INSCRICAO     NU_ANO  TP_FAIXA_ETARIA  TP_SEXO  TP_ESTADO_CIVIL  \
# count   4.332944e+06  4332944.0     4.332944e+06  4332944     4.332944e+06
# unique           NaN        NaN              NaN        2              NaN
# top              NaN        NaN              NaN        F              NaN
# freq             NaN        NaN              NaN  2624621              NaN
# mean    2.100643e+11     2024.0     4.803929e+00      NaN     1.034212e+00
# std     1.279403e+06        0.0     3.825449e+00      NaN     4.085476e-01
# min     2.100621e+11     2024.0     1.000000e+00      NaN     0.000000e+00
# 25%     2.100632e+11     2024.0     2.000000e+00      NaN     1.000000e+00
# 50%     2.100643e+11     2024.0     3.000000e+00      NaN     1.000000e+00
# 75%     2.100654e+11     2024.0     6.000000e+00      NaN     1.000000e+00
# max     2.100665e+11     2024.0     2.000000e+01      NaN     4.000000e+00
#
# ...
